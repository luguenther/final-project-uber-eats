# %% [markdown]
# # Load libraries

# %%
import numpy as np
import pandas as pd
import mysql.connector

# %% [markdown]
# # Load data

# %%
# Ensure the correct file paths
restaurants_file = "../data/restaurants_cleaned.csv"
cuisines_file = "../data/restaurant_cuisines.csv"
menus_file = "../data/cleaned_restaurant_menus.csv"

# Load the datasets
restaurants_df = pd.read_csv(restaurants_file)
cuisines_df = pd.read_csv(cuisines_file)
menus_df = pd.read_csv(menus_file)

# Replace string "nan" and empty strings with None
menus_df = menus_df.replace("nan", None)
menus_df = menus_df.replace("", None)

restaurants_df = restaurants_df.replace("nan", None)
restaurants_df = restaurants_df.replace("", None)

cuisines_df = cuisines_df.replace("nan", None)
cuisines_df = cuisines_df.replace("", None)

# Debugging: Check if data was loaded properly
print("Restaurants CSV Rows:", restaurants_df.shape[0])
print("Cuisines CSV Rows:", cuisines_df.shape[0])
print("Menus CSV Rows:", menus_df.shape[0])

print("First 5 rows of Restaurants CSV:")
display(restaurants_df.head())
# Out:
# Restaurants CSV Rows: 63468
# Cuisines CSV Rows: 232409
# Menus CSV Rows: 966780
# First 5 rows of Restaurants CSV:
#    id  position                                            name  score  \
# 0   1        19               PJ Fresh (224 Daniel Payne Drive)    0.0
# 1   2         9                  J' ti`'z Smoothie-N-Coffee Bar    0.0
# 2   3         6  Philly Fresh Cheesesteaks (541-B Graymont Ave)    0.0
# 3   4        17         Papa Murphy's (1580 Montgomery Highway)    0.0
# 4   5       162                Nelson Brothers Cafe (17th St N)    4.7
#
#    ratings                                          category    price_range  \
# 0      0.0                     Burgers, American, Sandwiches          Cheap
# 1      0.0  Coffee and Tea, Breakfast and Brunch, Bubble Tea  Not Available
# 2      0.0        American, Cheesesteak, Sandwiches, Alcohol          Cheap
# 3      0.0                                             Pizza          Cheap
# 4     22.0         Breakfast and Brunch, Burgers, Sandwiches  Not Available
#
#                                         full_address zip_code        lat  \
# 0      224 Daniel Payne Drive, Birmingham, AL, 35207    35207  33.562365
# 1  1521 Pinson Valley Parkway, Birmingham, AL, 35217    35217  33.583640
# 2          541-B Graymont Ave, Birmingham, AL, 35204    35204  33.509800
# 3         1580 Montgomery Highway, Hoover, AL, 35226    35226  33.404439
# 4               314 17th St N, Birmingham, AL, 35203    35203  33.514730
#
#          lng
# 0 -86.830703
# 1 -86.773330
# 2 -86.854640
# 3 -86.806614
# 4 -86.811700

# %%
restaurants_df = pd.read_csv(restaurants_file, na_values=["nan", "NaN", "NULL"])
cuisines_df = pd.read_csv(cuisines_file, na_values=["nan", "NaN", "NULL"])
menus_df = pd.read_csv(menus_file, na_values=["nan", "NaN", "NULL"])

# %%
restaurants_df = restaurants_df.replace({np.nan: None})
menus_df = menus_df.replace({np.nan: None})
cuisines_df = cuisines_df.replace({np.nan: None})

# %%
# Drop the 'description' column
menus_df.drop(columns=["description"], inplace=True)

# Verify the column is removed
print("Menus dataframe columns after dropping 'description':")
print(menus_df.columns)
# Out:
# Menus dataframe columns after dropping 'description':
# Index(['restaurant_id', 'category', 'name', 'price', 'price_str'], dtype='object')

# %%
restaurants_df["price_range"] = restaurants_df["price_range"].str.strip()  # Remove spaces
restaurants_df["price_range"] = restaurants_df["price_range"].str.replace(r'\s+', ' ', regex=True)  # Remove double spaces
restaurants_df["price_range"] = restaurants_df["price_range"].astype(str)  # Ensure it's a string

# Re-check the max length
print(restaurants_df["price_range"].str.len().max())  # Should still be 14
print(restaurants_df["price_range"].unique())  # Ensure values look normal
# Out:
# 14
# ['Cheap' 'Not Available' 'Moderate' 'Expensive' 'Very Expensive']

# %%
# Replace string "nan" and empty strings with None
menus_df = menus_df.replace("nan", None)
menus_df = menus_df.replace("", None)

restaurants_df = restaurants_df.replace("nan", None)
restaurants_df = restaurants_df.replace("", None)

cuisines_df = cuisines_df.replace("nan", None)
cuisines_df = cuisines_df.replace("", None)

# %%
# Replace NaN, "nan" strings, empty strings, and None with actual None values
menus_df = menus_df.replace({np.nan: None, "nan": None, "": None})
restaurants_df = restaurants_df.replace({np.nan: None, "nan": None, "": None})
cuisines_df = cuisines_df.replace({np.nan: None, "nan": None, "": None})

# %%
menus_df = menus_df.dropna()
restaurants_df = restaurants_df.dropna()
cuisines_df = cuisines_df.dropna()

# %%
# Check if any column contains the string "nan"
for column in menus_df.columns:
    print(f"{column}: {menus_df[column].astype(str).str.contains('nan').sum()} occurrences")

for column in restaurants_df.columns:
    print(f"{column}: {restaurants_df[column].astype(str).str.contains('nan').sum()} occurrences")

for column in cuisines_df.columns:
    print(f"{column}: {cuisines_df[column].astype(str).str.contains('nan').sum()} occurrences")
# Out:
# restaurant_id: 0 occurrences
# category: 0 occurrences
# name: 3214 occurrences
# price: 0 occurrences
# price_str: 0 occurrences
# id: 0 occurrences
# position: 0 occurrences
# name: 145 occurrences
# score: 0 occurrences
# ratings: 0 occurrences
# category: 1 occurrences
# price_range: 0 occurrences
# full_address: 161 occurrences
# zip_code: 0 occurrences
# lat: 0 occurrences
# lng: 0 occurrences
# restaurant_id: 0 occurrences
# cuisine_type: 1 occurrences

# %% [markdown]
# # Inserting data into MySQL database

# %%
restaurants_df.head()
# Out:
#    id  position                                            name  score  \
# 0   1        19               PJ Fresh (224 Daniel Payne Drive)    0.0
# 1   2         9                  J' ti`'z Smoothie-N-Coffee Bar    0.0
# 2   3         6  Philly Fresh Cheesesteaks (541-B Graymont Ave)    0.0
# 3   4        17         Papa Murphy's (1580 Montgomery Highway)    0.0
# 4   5       162                Nelson Brothers Cafe (17th St N)    4.7
#
#    ratings                                          category    price_range  \
# 0      0.0                     Burgers, American, Sandwiches          Cheap
# 1      0.0  Coffee and Tea, Breakfast and Brunch, Bubble Tea  Not Available
# 2      0.0        American, Cheesesteak, Sandwiches, Alcohol          Cheap
# 3      0.0                                             Pizza          Cheap
# 4     22.0         Breakfast and Brunch, Burgers, Sandwiches  Not Available
#
#                                         full_address zip_code        lat  \
# 0      224 Daniel Payne Drive, Birmingham, AL, 35207    35207  33.562365
# 1  1521 Pinson Valley Parkway, Birmingham, AL, 35217    35217  33.583640
# 2          541-B Graymont Ave, Birmingham, AL, 35204    35204  33.509800
# 3         1580 Montgomery Highway, Hoover, AL, 35226    35226  33.404439
# 4               314 17th St N, Birmingham, AL, 35203    35203  33.514730
#
#    longitude
# 0 -86.830703
# 1 -86.773330
# 2 -86.854640
# 3 -86.806614
# 4 -86.811700

# %%
restaurants_df["price_range"].apply(lambda x: len(x)).max()
# Out:
# np.int64(14)

# %%
# Step 1: Connect to MySQL
conn = mysql.connector.connect(
    host="localhost",        
    user="root",    
    password="root1234",  
    database="restaurants_db"
)
cursor = conn.cursor()

# Step 2: Fix MySQL Timeout Issues
cursor.execute("SET SESSION innodb_lock_wait_timeout = 300;")

# Step 3: Load CSV Files
restaurants_df = pd.read_csv("../data/clean/restaurants_cleaned.csv")
cuisines_df = pd.read_csv("../data/clean/restaurant_cuisines.csv")
menus_df = pd.read_csv("../data/clean/cleaned_restaurant_menus.csv")

# Step 4: Fix `lng` Column Name
restaurants_df.rename(columns={"lng": "longitude"}, inplace=True)

# Step 5: Fix 'price_range' Column
restaurants_df["price_range"] = restaurants_df["price_range"].astype(str).str[:50]  # Trim to max 50 chars

# Step 6: Remove Invalid Foreign Keys
valid_restaurant_ids = set(restaurants_df["id"])  # Get valid restaurant IDs
cuisines_df = cuisines_df[cuisines_df["restaurant_id"].isin(valid_restaurant_ids)]  # Remove invalid IDs

# Step 7: Insert Data in Smaller Batches
def insert_batch(cursor, conn, query, data, batch_size=500):
    """Insert data in smaller batches to avoid lock timeout"""
    for i in range(0, len(data), batch_size):
        batch = data[i:i + batch_size]
        try:
            cursor.executemany(query, batch)
            conn.commit()  # Commit after every batch
        except Exception as e:
            print(f"Error inserting batch {i} to {i+batch_size}: {e}")
            conn.rollback()  # Rollback if error occurs

# Insert into `restaurants` table
restaurant_values = [
    (
        row["id"], row["name"], row["score"], row["ratings"],
        row["price_range"]
    ) 
    for _, row in restaurants_df.iterrows()
]

insert_batch(cursor, conn, """
    INSERT INTO restaurants (restaurantID, name, score, ratings, price_range)
    VALUES (%s, %s, %s, %s, %s)
    ON DUPLICATE KEY UPDATE name=VALUES(name);
""", restaurant_values)

# Insert into `restaurant_cuisines` table (Foreign Key Fix Applied)
cuisine_values = [
    (row["restaurant_id"], row["cuisine_type"])
    for _, row in cuisines_df.iterrows()
]

insert_batch(cursor, conn, """
    INSERT INTO restaurant_cuisines (type)
    VALUES (%s);
""", cuisine_values)

# Insert into `restaurant_menus` table
menu_values = [
    (row["restaurant_id"], row["category"], row["name"], row["description"], row["price"])
    for _, row in menus_df.iterrows()
]

insert_batch(cursor, conn, """
    INSERT INTO restaurant_menus (restaurant_id, category, name, description, price)
    VALUES (%s, %s, %s, %s, %s);
""", menu_values)

# Close Connection
conn.close()
print("MySQL database successfully created and populated!")
# Out:
# Error inserting batch 0 to 500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 500 to 1000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 1000 to 1500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 1500 to 2000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 2000 to 2500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 2500 to 3000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 3000 to 3500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 3500 to 4000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 4000 to 4500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 4500 to 5000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 5000 to 5500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 5500 to 6000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 6000 to 6500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 6500 to 7000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 7000 to 7500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 7500 to 8000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 8000 to 8500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 8500 to 9000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 9000 to 9500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 9500 to 10000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 10000 to 10500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 10500 to 11000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 11000 to 11500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 11500 to 12000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 12000 to 12500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 12500 to 13000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 13000 to 13500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 13500 to 14000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 14000 to 14500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 14500 to 15000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 15000 to 15500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 15500 to 16000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 16000 to 16500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 16500 to 17000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 17000 to 17500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 17500 to 18000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 18000 to 18500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 18500 to 19000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 19000 to 19500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 19500 to 20000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 20000 to 20500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 20500 to 21000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 21000 to 21500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 21500 to 22000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 22000 to 22500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 22500 to 23000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 23000 to 23500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 23500 to 24000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 24000 to 24500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 24500 to 25000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 25000 to 25500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 25500 to 26000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 26000 to 26500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 26500 to 27000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 27000 to 27500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 27500 to 28000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 28000 to 28500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 28500 to 29000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 29000 to 29500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 29500 to 30000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 30000 to 30500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 30500 to 31000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 31000 to 31500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 31500 to 32000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 32000 to 32500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 32500 to 33000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 33000 to 33500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 33500 to 34000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 34000 to 34500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 34500 to 35000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 35000 to 35500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 35500 to 36000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 36000 to 36500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 36500 to 37000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 37000 to 37500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 37500 to 38000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 38000 to 38500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 38500 to 39000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 39000 to 39500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 39500 to 40000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 40000 to 40500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 40500 to 41000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 41000 to 41500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 41500 to 42000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 42000 to 42500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 42500 to 43000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 43000 to 43500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 43500 to 44000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 44000 to 44500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 44500 to 45000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 45000 to 45500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 45500 to 46000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 46000 to 46500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 46500 to 47000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 47000 to 47500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 47500 to 48000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 48000 to 48500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 48500 to 49000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 49000 to 49500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 49500 to 50000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 50000 to 50500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 50500 to 51000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 51000 to 51500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 51500 to 52000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 52000 to 52500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 52500 to 53000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 53000 to 53500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 53500 to 54000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 54000 to 54500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 54500 to 55000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 55000 to 55500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 55500 to 56000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 56000 to 56500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 56500 to 57000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 57000 to 57500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 57500 to 58000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 58000 to 58500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 58500 to 59000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 59000 to 59500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 59500 to 60000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 60000 to 60500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 60500 to 61000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 61000 to 61500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 61500 to 62000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 62000 to 62500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 62500 to 63000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 63000 to 63500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 63500 to 64000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 64000 to 64500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 64500 to 65000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 65000 to 65500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 65500 to 66000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 66000 to 66500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 66500 to 67000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 67000 to 67500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 67500 to 68000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 68000 to 68500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 68500 to 69000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 69000 to 69500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 69500 to 70000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 70000 to 70500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 70500 to 71000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 71000 to 71500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 71500 to 72000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 72000 to 72500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 72500 to 73000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 73000 to 73500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 73500 to 74000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 74000 to 74500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 74500 to 75000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 75000 to 75500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 75500 to 76000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 76000 to 76500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 76500 to 77000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 77000 to 77500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 77500 to 78000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 78000 to 78500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 78500 to 79000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 79000 to 79500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 79500 to 80000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 80000 to 80500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 80500 to 81000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 81000 to 81500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 81500 to 82000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 82000 to 82500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 82500 to 83000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 83000 to 83500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 83500 to 84000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 84000 to 84500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 84500 to 85000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 85000 to 85500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 85500 to 86000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 86000 to 86500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 86500 to 87000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 87000 to 87500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 87500 to 88000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 88000 to 88500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 88500 to 89000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 89000 to 89500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 89500 to 90000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 90000 to 90500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 90500 to 91000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 91000 to 91500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 91500 to 92000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 92000 to 92500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 92500 to 93000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 93000 to 93500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 93500 to 94000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 94000 to 94500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 94500 to 95000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 95000 to 95500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 95500 to 96000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 96000 to 96500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 96500 to 97000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 97000 to 97500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 97500 to 98000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 98000 to 98500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 98500 to 99000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 99000 to 99500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 99500 to 100000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 100000 to 100500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 100500 to 101000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 101000 to 101500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 101500 to 102000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 102000 to 102500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 102500 to 103000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 103000 to 103500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 103500 to 104000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 104000 to 104500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 104500 to 105000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 105000 to 105500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 105500 to 106000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 106000 to 106500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 106500 to 107000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 107000 to 107500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 107500 to 108000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 108000 to 108500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 108500 to 109000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 109000 to 109500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 109500 to 110000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 110000 to 110500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 110500 to 111000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 111000 to 111500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 111500 to 112000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 112000 to 112500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 112500 to 113000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 113000 to 113500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 113500 to 114000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 114000 to 114500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 114500 to 115000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 115000 to 115500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 115500 to 116000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 116000 to 116500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 116500 to 117000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 117000 to 117500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 117500 to 118000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 118000 to 118500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 118500 to 119000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 119000 to 119500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 119500 to 120000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 120000 to 120500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 120500 to 121000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 121000 to 121500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 121500 to 122000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 122000 to 122500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 122500 to 123000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 123000 to 123500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 123500 to 124000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 124000 to 124500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 124500 to 125000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 125000 to 125500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 125500 to 126000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 126000 to 126500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 126500 to 127000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 127000 to 127500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 127500 to 128000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 128000 to 128500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 128500 to 129000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 129000 to 129500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 129500 to 130000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 130000 to 130500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 130500 to 131000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 131000 to 131500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 131500 to 132000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 132000 to 132500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 132500 to 133000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 133000 to 133500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 133500 to 134000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 134000 to 134500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 134500 to 135000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 135000 to 135500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 135500 to 136000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 136000 to 136500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 136500 to 137000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 137000 to 137500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 137500 to 138000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 138000 to 138500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 138500 to 139000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 139000 to 139500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 139500 to 140000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 140000 to 140500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 140500 to 141000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 141000 to 141500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 141500 to 142000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 142000 to 142500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 142500 to 143000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 143000 to 143500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 143500 to 144000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 144000 to 144500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 144500 to 145000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 145000 to 145500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 145500 to 146000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 146000 to 146500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 146500 to 147000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 147000 to 147500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 147500 to 148000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 148000 to 148500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 148500 to 149000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 149000 to 149500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 149500 to 150000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 150000 to 150500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 150500 to 151000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 151000 to 151500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 151500 to 152000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 152000 to 152500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 152500 to 153000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 153000 to 153500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 153500 to 154000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 154000 to 154500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 154500 to 155000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 155000 to 155500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 155500 to 156000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 156000 to 156500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 156500 to 157000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 157000 to 157500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 157500 to 158000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 158000 to 158500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 158500 to 159000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 159000 to 159500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 159500 to 160000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 160000 to 160500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 160500 to 161000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 161000 to 161500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 161500 to 162000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 162000 to 162500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 162500 to 163000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 163000 to 163500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 163500 to 164000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 164000 to 164500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 164500 to 165000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 165000 to 165500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 165500 to 166000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 166000 to 166500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 166500 to 167000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 167000 to 167500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 167500 to 168000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 168000 to 168500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 168500 to 169000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 169000 to 169500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 169500 to 170000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 170000 to 170500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 170500 to 171000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 171000 to 171500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 171500 to 172000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 172000 to 172500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 172500 to 173000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 173000 to 173500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 173500 to 174000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 174000 to 174500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 174500 to 175000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 175000 to 175500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 175500 to 176000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 176000 to 176500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 176500 to 177000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 177000 to 177500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 177500 to 178000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 178000 to 178500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 178500 to 179000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 179000 to 179500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 179500 to 180000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 180000 to 180500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 180500 to 181000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 181000 to 181500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 181500 to 182000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 182000 to 182500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 182500 to 183000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 183000 to 183500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 183500 to 184000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 184000 to 184500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 184500 to 185000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 185000 to 185500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 185500 to 186000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 186000 to 186500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 186500 to 187000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 187000 to 187500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 187500 to 188000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 188000 to 188500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 188500 to 189000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 189000 to 189500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 189500 to 190000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 190000 to 190500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 190500 to 191000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 191000 to 191500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 191500 to 192000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 192000 to 192500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 192500 to 193000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 193000 to 193500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 193500 to 194000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 194000 to 194500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 194500 to 195000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 195000 to 195500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 195500 to 196000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 196000 to 196500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 196500 to 197000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 197000 to 197500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 197500 to 198000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 198000 to 198500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 198500 to 199000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 199000 to 199500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 199500 to 200000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 200000 to 200500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 200500 to 201000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 201000 to 201500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 201500 to 202000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 202000 to 202500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 202500 to 203000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 203000 to 203500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 203500 to 204000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 204000 to 204500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 204500 to 205000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 205000 to 205500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 205500 to 206000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 206000 to 206500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 206500 to 207000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 207000 to 207500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 207500 to 208000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 208000 to 208500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 208500 to 209000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 209000 to 209500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 209500 to 210000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 210000 to 210500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 210500 to 211000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 211000 to 211500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 211500 to 212000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 212000 to 212500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 212500 to 213000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 213000 to 213500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 213500 to 214000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 214000 to 214500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 214500 to 215000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 215000 to 215500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 215500 to 216000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 216000 to 216500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 216500 to 217000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 217000 to 217500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 217500 to 218000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 218000 to 218500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 218500 to 219000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 219000 to 219500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 219500 to 220000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 220000 to 220500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 220500 to 221000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 221000 to 221500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 221500 to 222000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 222000 to 222500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 222500 to 223000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 223000 to 223500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 223500 to 224000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 224000 to 224500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 224500 to 225000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 225000 to 225500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 225500 to 226000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 226000 to 226500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 226500 to 227000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 227000 to 227500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 227500 to 228000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 228000 to 228500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 228500 to 229000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 229000 to 229500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 229500 to 230000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 230000 to 230500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 230500 to 231000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 231000 to 231500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 231500 to 232000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 232000 to 232500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 232500 to 233000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 233000 to 233500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 233500 to 234000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 234000 to 234500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 234500 to 235000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 235000 to 235500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 235500 to 236000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 236000 to 236500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 236500 to 237000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 237000 to 237500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 237500 to 238000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 238000 to 238500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 238500 to 239000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 239000 to 239500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 239500 to 240000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 240000 to 240500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 240500 to 241000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 241000 to 241500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 241500 to 242000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 242000 to 242500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 242500 to 243000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 243000 to 243500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 243500 to 244000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 244000 to 244500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 244500 to 245000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 245000 to 245500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 245500 to 246000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 246000 to 246500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 246500 to 247000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 247000 to 247500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 247500 to 248000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 248000 to 248500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 248500 to 249000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 249000 to 249500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 249500 to 250000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 250000 to 250500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 250500 to 251000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 251000 to 251500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 251500 to 252000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 252000 to 252500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 252500 to 253000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 253000 to 253500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 253500 to 254000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 254000 to 254500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 254500 to 255000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 255000 to 255500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 255500 to 256000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 256000 to 256500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 256500 to 257000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 257000 to 257500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 257500 to 258000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 258000 to 258500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 258500 to 259000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 259000 to 259500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 259500 to 260000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 260000 to 260500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 260500 to 261000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 261000 to 261500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 261500 to 262000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 262000 to 262500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 262500 to 263000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 263000 to 263500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 263500 to 264000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 264000 to 264500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 264500 to 265000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 265000 to 265500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 265500 to 266000: 1054 (42S22): Unknown column 'nan' in 'field list'
# ...
# Error inserting batch 879500 to 880000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 880000 to 880500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 880500 to 881000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 881000 to 881500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 881500 to 882000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 882000 to 882500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 882500 to 883000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 883000 to 883500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 883500 to 884000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 884000 to 884500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 884500 to 885000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 885000 to 885500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 885500 to 886000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 886000 to 886500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 886500 to 887000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 887000 to 887500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 887500 to 888000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 888000 to 888500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 888500 to 889000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 889000 to 889500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 889500 to 890000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 890000 to 890500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 890500 to 891000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 891000 to 891500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 891500 to 892000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 892000 to 892500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 892500 to 893000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 893000 to 893500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 893500 to 894000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 894000 to 894500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 894500 to 895000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 895000 to 895500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 895500 to 896000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 896000 to 896500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 896500 to 897000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 897000 to 897500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 897500 to 898000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 898000 to 898500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 898500 to 899000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 899000 to 899500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 899500 to 900000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 900000 to 900500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 900500 to 901000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 901000 to 901500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 901500 to 902000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 902000 to 902500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 902500 to 903000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 903000 to 903500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 903500 to 904000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 904000 to 904500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 904500 to 905000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 905000 to 905500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 905500 to 906000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 906000 to 906500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 906500 to 907000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 907000 to 907500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 907500 to 908000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 908000 to 908500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 908500 to 909000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 909000 to 909500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 909500 to 910000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 910000 to 910500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 910500 to 911000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 911000 to 911500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 911500 to 912000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 912000 to 912500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 912500 to 913000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 913000 to 913500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 913500 to 914000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 914000 to 914500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 914500 to 915000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 915000 to 915500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 915500 to 916000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 916000 to 916500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 916500 to 917000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 917000 to 917500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 917500 to 918000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 918000 to 918500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 918500 to 919000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 919000 to 919500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 919500 to 920000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 920000 to 920500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 920500 to 921000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 921000 to 921500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 921500 to 922000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 922000 to 922500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 922500 to 923000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 923000 to 923500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 923500 to 924000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 924000 to 924500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 924500 to 925000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 925000 to 925500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 925500 to 926000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 926000 to 926500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 926500 to 927000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 927000 to 927500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 927500 to 928000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 928000 to 928500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 928500 to 929000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 929000 to 929500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 929500 to 930000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 930000 to 930500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 930500 to 931000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 931000 to 931500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 931500 to 932000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 932000 to 932500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 932500 to 933000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 933000 to 933500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 933500 to 934000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 934000 to 934500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 934500 to 935000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 935000 to 935500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 935500 to 936000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 936000 to 936500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 936500 to 937000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 937000 to 937500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 937500 to 938000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 938000 to 938500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 938500 to 939000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 939000 to 939500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 939500 to 940000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 940000 to 940500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 940500 to 941000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 941000 to 941500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 941500 to 942000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 942000 to 942500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 942500 to 943000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 943000 to 943500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 943500 to 944000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 944000 to 944500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 944500 to 945000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 945000 to 945500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 945500 to 946000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 946000 to 946500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 946500 to 947000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 947000 to 947500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 947500 to 948000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 948000 to 948500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 948500 to 949000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 949000 to 949500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 949500 to 950000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 950000 to 950500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 950500 to 951000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 951000 to 951500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 951500 to 952000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 952000 to 952500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 952500 to 953000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 953000 to 953500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 953500 to 954000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 954000 to 954500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 954500 to 955000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 955000 to 955500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 955500 to 956000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 956000 to 956500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 956500 to 957000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 957000 to 957500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 957500 to 958000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 958000 to 958500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 958500 to 959000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 959000 to 959500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 959500 to 960000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 960000 to 960500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 960500 to 961000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 961000 to 961500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 961500 to 962000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 962000 to 962500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 962500 to 963000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 963000 to 963500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 963500 to 964000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 964000 to 964500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 964500 to 965000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 965000 to 965500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 965500 to 966000: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 966000 to 966500: 1054 (42S22): Unknown column 'nan' in 'field list'
# Error inserting batch 966500 to 967000: 1054 (42S22): Unknown column 'nan' in 'field list'
# MySQL database successfully created and populated!
